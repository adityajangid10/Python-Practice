# %%
import pandas as pd

# %%
df = pd.read_csv("/content/duplicate_records.csv")
print(df)
# Out:
#           Category         Region        Status  Rating Priority Flagged
# 0      Electronics  North America  Out of Stock       2   Medium     Yes
# 1      Electronics   Asia Pacific      In Stock       3     High     Yes
# 2    Home & Garden  North America      In Stock       2   Medium     Yes
# 3          Apparel   Asia Pacific  Out of Stock       1      Low      No
# 4          Apparel  North America  Out of Stock       1     High      No
# ..             ...            ...           ...     ...      ...     ...
# 295        Apparel  North America      In Stock       2      Low     Yes
# 296         Sports  North America  Out of Stock       4      Low     Yes
# 297         Sports   Asia Pacific      In Stock       5     High     Yes
# 298    Electronics         Europe   Backordered       3     High      No
# 299    Electronics  North America      In Stock       1     High     Yes
#
# [300 rows x 6 columns]

# %%
print(df.duplicated().sum())
# Out:
# 36

# %%
new_data = df.drop_duplicates() # without inplace it only returns a copy
                                # of the data
df.drop_duplicate(inplace = True) # changes original

# %%
print(df.duplicated().sum())
print(df.shape)
# Out:
# 0
# (264, 6)

# %%
data = {"name" : ["virat", "mohit", "rohit", "mohit","mohit"],
        "age":[25,31,30,31,31],
        "city":["Jaipur", "Gurgaon", "Rewari", "Gurgaon","Gurgaon"]}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari
# 3  mohit   31  Gurgaon
# 4  mohit   31  Gurgaon

# %%
print(df.duplicated().sum())
df.drop_duplicates(inplace= True)
print(df.duplicated().sum())
# Out:
# 2
# 0

# %%
print(df)
# Out:
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari

# %%
data = {"name" : ["virat", "mohit", "rohit", "mohit","mohit"],
        "age":[25,31,30,31,31],
        "city":["Jaipur", "Gurgaon", "Rewari", "Gurgaon","Gurgaon"]}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari
# 3  mohit   31  Gurgaon
# 4  mohit   31  Gurgaon

# %%
new_data = df.drop_duplicates() # inplace = True
print(new_data)
print()
print(df)
# Out:
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari
#
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari
# 3  mohit   31  Gurgaon
# 4  mohit   31  Gurgaon

# %%
new_data = df.drop_duplicates() # inplace = True
df.drop_duplicates(inplace = True)
print(new_data)
print()
print(df)
# Out:
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari
#
#     name  age     city
# 0  virat   25   Jaipur
# 1  mohit   31  Gurgaon
# 2  rohit   30   Rewari
