# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajangid10/Python-Practice/blob/main/pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pie chart
# a pie chart shows how a  total is divided among different categories
import matplotlib.pyplot as plt
values = [30,40,50,20,15]
student = ['a','b','c','d','e']

plt.pie(values, labels = student ,autopct = '%1.1f%%')
plt.show()

# %%
# plot pie charts for all the following data in one place using subplot
# Set 1 Labels & Numerical Values
labels_smartphone = ["Apple", "Samsung", "Xiaomi", "Oppo", "Others"]
sizes_smartphone = [21.5, 19.8, 13.2, 8.5, 37.0]

# Set 2 Labels & Numerical Values
labels_budget = ["Housing", "Food & Groceries", "Transportation", "Savings", "Entertainment"]
sizes_budget = [35, 20, 15, 20, 10]

# Set 3 Labels & Numerical Values
labels_atmosphere = ["Nitrogen", "Oxygen", "Argon", "Carbon Dioxide", "Neon & Others"]
sizes_atmosphere = [78.08, 20.95, 0.93, 0.04, 0.00]

# Set 4 Labels & Numerical Values
labels_gaming = ["PC", "PlayStation", "Xbox", "Nintendo Switch", "Mobile"]
sizes_gaming = [24, 22, 18, 16, 20]



plt.subplot(2, 2, 1)
plt.pie(sizes_smartphone,labels=labels_smartphone,autopct='%1.1f%%')
plt.title("Smartphone Market Share")

plt.subplot(2, 2, 2)
plt.pie(sizes_budget,labels=labels_budget,autopct='%1.1f%%')
plt.title("Monthly Budget")

plt.subplot(2, 2, 3)
plt.pie(sizes_atmosphere,labels=labels_atmosphere,autopct='%1.1f%%')
plt.title("Earth's Atmosphere")

plt.subplot(2, 2, 4)
plt.pie(sizes_gaming,labels=labels_gaming,autopct='%1.1f%%')
plt.title("Gaming Platform")

plt.tight_layout()

plt.show()
