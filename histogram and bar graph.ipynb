# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajangid10/Python-Practice/blob/main/histogram%20and%20bar%20graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
A histogram is a graph showing frequency distribution.
it is a graph showing the number of observations with each given interval.

in matplotlib we use the hist() function to create histograms.
it will take an array of numbers to create a histogram, the array is sent into the function
as an argument.
"""
# Out:
# '\nA histogram is a graph showing frequency distribution.\nit is a graph showing the number of observations with each given interval.\n\nin matplotlib we use the hist() function to create histograms.\nit will take an array of numbers to create a histogram, the array is sent into the function\nas an argument.\n'

# %%
import matplotlib.pyplot as plt

# %%
marks = [35,42,48,51,54,55,56,32,43,90,80,82,67,87,65,56,77,88,99,55,44,33,22,11,85]
plt.hist(marks,edgecolor='black')
plt.title('Marks of Students')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# %%
# bar graph :- A Bar graph compares different categories with according to their quantities.



courses = ["Python", "Java", "Data Science", "Web Dev"]
students = [40, 25, 35, 30]
plt.xlabel("Courses")
plt.ylabel("number of Students")
plt.title("Students enrollment")
plt.bar(courses, students)
plt.show()

# %%
data1 = [69, 27, 17, 90, 79, 24, 19, 76, 73, 91, 93, 73, 20, 71, 46, 65, 59, 53, 16, 78, 47, 26, 54, 56, 81, 1, 32, 40, 54, 71, 82, 19, 14, 74, 74, 76, 86, 21, 14, 43, 84, 93, 73, 3, 71, 8, 58, 69, 23, 6, 92, 9, 68, 18, 61, 16, 52, 74, 88, 59, 9, 20, 55, 21, 34, 70, 41, 89, 6, 82, 20, 97, 49, 68, 16, 84, 33, 72, 70, 80, 48, 75, 88, 95, 32, 43, 23, 58, 14, 47, 26, 17, 35, 55, 47, 65, 58, 34, 75, 58]
data2 = [43, 50, 16, 78, 39, 68, 97, 67, 44, 68, 74, 25, 12, 36, 61, 31, 74, 67, 26, 70, 78, 55, 22, 9, 31, 38, 23, 52, 93, 87, 7, 7, 86, 11, 18, 73, 30, 3, 45, 33, 90, 84, 31, 48, 40, 49, 2, 92, 14, 60, 32, 53, 91, 54, 19, 45, 37, 78, 37, 74, 35, 16, 31, 82, 71, 36, 33, 28, 42, 91, 19, 79, 11, 18, 73, 99, 2, 30, 100, 39, 24, 24, 13, 26, 18, 17, 39, 40, 33, 1, 58, 56, 58, 31, 92, 89, 41, 74, 88, 65]
data3 = [83, 62, 24, 19, 2, 30, 40, 62, 95, 95, 83, 97, 72, 56, 60, 31, 11, 73, 45, 92, 44, 14, 77, 34, 44, 6, 38, 31, 23, 65, 28, 77, 32, 57, 35, 99, 26, 7, 79, 37, 33, 2, 95, 78, 19, 91, 90, 69, 88, 54, 80, 96, 99, 77, 88, 86, 47, 3, 80, 56, 21, 46, 90, 96, 76, 98, 47, 78, 17, 27, 81, 23, 67, 97, 17, 13, 41, 10, 46, 83, 54, 61, 50, 88, 16, 55, 62, 23, 86, 71, 10, 22, 22, 99, 88, 54, 12, 34, 50, 43]
data4 = [95, 95, 79, 21, 51, 48, 54, 1, 24, 57, 62, 54, 90, 9, 88, 76, 87, 79, 8, 69, 40, 43, 80, 87, 96, 60, 61, 64, 59, 23, 2, 40, 23, 52, 64, 58, 93, 33, 94, 31, 65, 33, 57, 75, 23, 2, 36, 98, 23, 70, 30, 100, 41, 85, 36, 32, 68, 20, 1, 39, 49, 96, 82, 9, 12, 64, 66, 89, 38, 38, 31, 97, 11, 65, 99, 74, 23, 100, 24, 37, 70, 2, 74, 90, 40, 55, 86, 63, 17, 99, 37, 61, 80, 45, 79, 19, 4, 89, 29, 7]

plt.subplot(2, 2, 1)
plt.hist(data1, color='blue', edgecolor='black')
plt.title('Data 1')
plt.subplot(2, 2, 2)
plt.hist(data2, color='red', edgecolor='black')
plt.title('Data 2')
plt.subplot(2, 2, 3)
plt.hist(data3, color='green', edgecolor='black')
plt.title('Data 3')
plt.subplot(2, 2, 4)
plt.hist(data4, color='yellow', edgecolor='black')
plt.title('Data 4')

plt.tight_layout()
plt.show()

# %%
category1 = ["Smartphones", "Laptops", "Tablets", "Smartwatches", "Headphones", "Monitors", "Keyboards", "Printers"]
quantity1 = [142, 85, 64, 110, 135, 45, 92, 28]

category2 = ["Notebooks", "Gel Pens", "Highlighters", "Binder Clips", "Printer Paper", "Sticky Notes", "Staplers", "File Folders"]
quantity2 = [75, 120, 45, 150, 60, 115, 15, 88]

category3 = ["Apples", "Bananas", "Avocados", "Tomatoes", "Spinach", "Carrots", "Strawberries", "Oranges"]
quantity3 = [95, 130, 40, 85, 55, 70, 65, 105]

category4 = ["Espresso", "Latte", "Cappuccino", "Croissants", "Muffins", "Iced Tea", "Sandwiches", "Cookies"]
quantity4 = [110, 145, 95, 60, 45, 80, 50, 125]


plt.subplot(2, 2, 1)
plt.bar(category1, quantity1, color='blue')
plt.title("Tech Products")
plt.xticks(rotation=45, ha='right')

plt.subplot(2, 2, 2)
plt.bar(category2, quantity2, color='red')
plt.title("Office Supplies")
plt.xticks(rotation=45, ha='right')

plt.subplot(2, 2, 3)
plt.bar(category3, quantity3, color='green')
plt.title("Grocery Items")
plt.xticks(rotation=45, ha='right')

plt.subplot(2, 2, 4)
plt.bar(category4, quantity4, color='yellow')
plt.title("Cafe Sales")
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
